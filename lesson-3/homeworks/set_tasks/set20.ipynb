# %%
a = {10, 20, 30}
b = {40, 50, 60}

is_disjoint = a.isdisjoint(b)
print(is_disjoint)
# Out:
# True

# %%
a = {10, 20, 30}
b = {30, 50, 60}

is_disjoint = a.isdisjoint(b)
print(is_disjoint)
# Out:
# False
