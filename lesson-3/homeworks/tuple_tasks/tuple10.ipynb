# %%
t = (20, 30, 40, 50)

if len(t) == 0:
    print("Empty Tuple:")
else:
    print("Don't Empty:")
# Out:
# Don't Empty:

# %%
t = ()

if len(t) == 0:
    print("Empty Tuple:")
else:
    print("Don't Empty:")
# Out:
# Empty Tuple:
