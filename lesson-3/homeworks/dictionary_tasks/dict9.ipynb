# %%
my_dict = {}

if  not my_dict:
    print("Dictionary Empty:")
else:
    print("Don't Empty")
# Out:
# Dictionary Empty:

# %%
my_dict = {"a": 167}

if  not my_dict:
    print("Dictionary Empty:")
else:
    print("Don't Empty")
# Out:
# Don't Empty
