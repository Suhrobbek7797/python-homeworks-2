# %%
person = {
    'Name': "Jonathan",
    'Email': "John1966",
    'Age': "59"
}

type(person)
# Out:
# dict

# %%
person['Name']
# Out:
# 'Jonathan'

# %%
person['Email']
# Out:
# 'John1966'

# %%
person['Age']
# Out:
# '59'
