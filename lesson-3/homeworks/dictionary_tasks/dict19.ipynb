# %%
my_dict = {"a": 1, "b": 2, "c": 1, "d": 3, "e": 2}

unique_count = len(set(my_dict.values()))
print(unique_count)
# Out:
# 3

# %%
my_dict = {"a": 1, "b": 2, "c": 1, "d": 1, "e": 2}

unique_count = len(set(my_dict.values()))
print(unique_count)
# Out:
# 2
