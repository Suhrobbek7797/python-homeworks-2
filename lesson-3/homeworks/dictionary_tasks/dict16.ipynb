# %%
my_dict = {"a": 1, 
           "b": {"x": 10, "y":20},
           "c": 3
}

result = any(isinstance(v, dict) for v in my_dict.values())
print(result)
# Out:
# True

# %%
my_dict = {"a": 1, 
           "b": 2,
           "c": 3
}

result = any(isinstance(v, dict) for v in my_dict.values())
print(result)
# Out:
# False
