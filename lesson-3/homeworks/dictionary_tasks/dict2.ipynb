# %%
person = {
    'Name': "Jonathan",
    'Email': "John1966",
    'Age': "59"
}

if 'Name' in person:
    print("Key Have")
else:
    print("Key Haven't")
# Out:
# Key Have

# %%
person = {
    'Name': "Jonathan",
    'Email': "John1966",
    'Age': "59"
}

if 'Location' in person:
    print("Key Have")
else:
    print("Key Haven't")
# Out:
# Key Haven't
